# %%
year = int(input("Enter the year which can be checkd for the leap year"))
if(year%4==0):
    if(year%100==0):
        if(year%400==0):
            print("this year is a leap !")
        else:
            print("this year is  not a leap year")   
    else:
        print(f"{year}year is a leap year",year)
else:
    print(f"the year is not a leap year!")
# Out:
# the year is not a leap year!

# %% [markdown]
# THIS IS THE CODE FOR THE LIST APPEND FUNCTION OF THE

# %%
inventory = ["apple","banans","graps","jackfruits","pitch","blueBerry"]
inventory.append("banana")

item=str(input("Enter the fruit which you will check if it is present in the inventry"))
if item in inventory:
    print("Item is present in this inventry")
else:
    print("The item is not prensent in this inventry")
# Out:
# Item is present in this inventry

# %%
def greet(name):
    print(f"Hey {name} welcome to the metaverse!")


greet("soham")
# Out:
# Hey soham welcome to the metaverse!

# %%
### veriable length arguments
###positional length arguments
def print_elements(*soumya):
    for i in soumya:
        print(i)
        
print_elements(1,2,3,4,5,6,"soumyajit")
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# soumyajit

# %% [markdown]
# positional and functinal arguments in the diffrent parameter

# %%
##positional and key word arguments
def positional_arguments(*args):
    for i in args:
        print(f"your arguments are{i}")
def keywords_arguments(**Positionalargs):
    for key,value in Positionalargs.items():
        print(f"{key},{value}")
        
positional_arguments(1,2,3,)
keywords_arguments(name="soumyajit",occupation="SoftwereEngineer",degree="Btech")
# Out:
# your arguments are1
# your arguments are2
# your arguments are3
# name,soumyajit
# occupation,SoftwereEngineer
# degree,Btech
